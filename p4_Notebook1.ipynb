# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # **Importation des librairies**

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # **Importation des bases de données**

# %%
df1= pd.read_csv(r"C:\Users\Rénato CATALFAMO\Desktop\aide_alimentaire.csv")

# %%
df2=pd.read_csv(r"C:\Users\Rénato CATALFAMO\Desktop\dispo_alimentaire.csv")

# %%
df2z=pd.read_csv(r"C:\Users\Rénato CATALFAMO\Desktop\dispo_alimentaire.csv") #

# %%
df2b=pd.read_csv(r"C:\Users\Rénato CATALFAMO\Desktop\dispo_alimentaire.csv") #

# %%
df3=pd.read_csv(r"C:\Users\Rénato CATALFAMO\Desktop\population.csv")

# %%
df4=pd.read_csv(r"C:\Users\Rénato CATALFAMO\Desktop\sous_nutrition.csv")

# %% [markdown]
# # **Etude de la proportion de la population en sous-nutrition dans le monde**

# %%
#### Question 1

#### Observation des 5 premières ligne de la base de donnée de sous-nutrition


df4.head()
# Out:
#           Zone      Année Valeur
# 0  Afghanistan  2012-2014    8.6
# 1  Afghanistan  2013-2015    8.8
# 2  Afghanistan  2014-2016    8.9
# 3  Afghanistan  2015-2017    9.7
# 4  Afghanistan  2016-2018   10.5

# %%
# Observation des 5 dernières lignes " " "  "

df4.tail()
# Out:
#           Zone      Année Valeur
# 1213  Zimbabwe  2013-2015    NaN
# 1214  Zimbabwe  2014-2016    NaN
# 1215  Zimbabwe  2015-2017    NaN
# 1216  Zimbabwe  2016-2018    NaN
# 1217  Zimbabwe  2017-2019    NaN

# %%
# Obervation de df4, et fitrage de la base de donnée de sous_nutriton pour 2017


df4_2017=df4['Année']=='2016-2018'

# %%
df4=df4[df4_2017]

# %%
df4
# Out:
#                                         Zone      Année Valeur
# 4                                Afghanistan  2016-2018   10.5
# 10                            Afrique du Sud  2016-2018    3.1
# 16                                   Albanie  2016-2018    0.1
# 22                                   Algérie  2016-2018    1.3
# 28                                 Allemagne  2016-2018    NaN
# ...                                      ...        ...    ...
# 1192  Venezuela (République bolivarienne du)  2016-2018      8
# 1198                                Viet Nam  2016-2018    6.5
# 1204                                   Yémen  2016-2018    NaN
# 1210                                  Zambie  2016-2018    NaN
# 1216                                Zimbabwe  2016-2018    NaN
#
# [203 rows x 3 columns]

# %%
# observation de la colonne Valeur 

df4["Valeur"]
# Out:
# 4       10.5
# 10       3.1
# 16       0.1
# 22       1.3
# 28       NaN
#         ...
# 1192       8
# 1198     6.5
# 1204     NaN
# 1210     NaN
# 1216     NaN
# Name: Valeur, Length: 203, dtype: object

# %%
# transforamtion des NaN en 0 pour réaliser la somme

df4.fillna(value={"Valeur": 0})
# Out:
#                                         Zone      Année Valeur
# 4                                Afghanistan  2016-2018   10.5
# 10                            Afrique du Sud  2016-2018    3.1
# 16                                   Albanie  2016-2018    0.1
# 22                                   Algérie  2016-2018    1.3
# 28                                 Allemagne  2016-2018      0
# ...                                      ...        ...    ...
# 1192  Venezuela (République bolivarienne du)  2016-2018      8
# 1198                                Viet Nam  2016-2018    6.5
# 1204                                   Yémen  2016-2018      0
# 1210                                  Zambie  2016-2018      0
# 1216                                Zimbabwe  2016-2018      0
#
# [203 rows x 3 columns]

# %%
x=df4.fillna(value={"Valeur": 0})

# %%
a=x['Valeur']

# %%
# remplacement des <0.1 par 0

c= a.replace("<0.1", 0)

# %%
# transformation en Numeric puis somme * 1000 000 (car definit en million)

resultat_ss_nutrition=pd.to_numeric(c, downcast="float").sum()*1000000

# %% [markdown]
# # **Population en sous-nutrition en 2017**

# %%
### resultat ss_nutrition 2017

round(resultat_ss_nutrition)
# Out:
# 535700012

# %%
### observation de la base de la population


df3
# Out:
#              Zone  Année     Valeur
# 0     Afghanistan   2013  32269.589
# 1     Afghanistan   2014  33370.794
# 2     Afghanistan   2015  34413.603
# 3     Afghanistan   2016  35383.032
# 4     Afghanistan   2017  36296.113
# ...           ...    ...        ...
# 1411     Zimbabwe   2014  13586.707
# 1412     Zimbabwe   2015  13814.629
# 1413     Zimbabwe   2016  14030.331
# 1414     Zimbabwe   2017  14236.595
# 1415     Zimbabwe   2018  14438.802
#
# [1416 rows x 3 columns]

# %%
### renomage de 'valeur'

df3.rename(columns={'Valeur': 'pop_total'}, inplace=True)

# %%
### filtrage pour 2017

df3_2017=df3['Année']==2017

# %%
df3=df3[df3_2017]

# %%
# Observation de la colonne 

df3['pop_total']
# Out:
# 4       36296.113
# 10      57009.756
# 16       2884.169
# 22      41389.189
# 28      82658.409
#           ...
# 1390    29402.484
# 1396    94600.648
# 1402    27834.819
# 1408    16853.599
# 1414    14236.595
# Name: pop_total, Length: 236, dtype: float64

# %%
# somme de la population en 2017

df3['pop_total'].sum()
# Out:
# 7548134.1110000005

# %%
resultat_pop=df3['pop_total'].sum()

# %% [markdown]
# # **Population en 2017**

# %%
# resultat de la pop

pop_mondiale_2017=round(resultat_pop*1000)

# %%
pop_mondiale_2017
# Out:
# 7548134111

# %%
# Proportion de personne qui sont en sous nutrition dans le monde 

result_final=((resultat_ss_nutrition)/(resultat_pop))*100

# %%
# Resultat arondie à l'entier

f=round(result_final,1)

# %% [markdown]
# # **Résultat de la proportion de sous-nutrition dans le monde.**

# %%
print('La proportion de la population en sous-nutrition dans le monde est de {:,} %'.format(f))
# Out:
# La proportion de la population en sous-nutrition dans le monde est de 7.1 %

# %%
### réprésentation en nombre dans la population mondiale

f1=round((7.1/100)*pop_mondiale_2017)

# %%
print('La population en sous-nutrition dans le monde représente {:,} personnes'.format(f1))
# Out:
# La population en sous-nutrition dans le monde représente 535,917,522 personnes

# %% [markdown]
# # **Représentation graphique**

# %%
###### Grapique en barre

names = ['population en sous-nutrition', 'population_mondiale'] 
values = [f, 100]

plt.ylabel('Population en pourcentage')
plt.title('Proportion de la population mondiale en sous-nutrition en 2017')
plt.bar(names, values)
X=plt.bar(names, values)
X[0].set_color('r')
X[1].set_color('b')

plt.show()

# %%
########################### question 2 ###########################################

# %% [markdown]
# # **Etude sur la disponiilité alimentaire mondiale**

# %%
df2z

# %%
df2z.rename(columns={'Disponibilité alimentaire (Kcal/personne/jour)': 'Disponibilité alimentaire'}, inplace=True)

# %%
############# sélection des colonnes utiles

df2z=df2z[['Zone', 'Produit', 'Origine','Disponibilité alimentaire']]

# %%
df2z
# Out:
#                Zone                Produit   Origine  \
# 0       Afghanistan       Abats Comestible   animale
# 1       Afghanistan        Agrumes, Autres  vegetale
# 2       Afghanistan  Aliments pour enfants  vegetale
# 3       Afghanistan                 Ananas  vegetale
# 4       Afghanistan                Bananes  vegetale
# ...             ...                    ...       ...
# 15600  Îles Salomon       Viande de Suides   animale
# 15601  Îles Salomon    Viande de Volailles   animale
# 15602  Îles Salomon          Viande, Autre   animale
# 15603  Îles Salomon                    Vin  vegetale
# 15604  Îles Salomon         Épices, Autres  vegetale
#
#        Disponibilité alimentaire
# 0                            5.0
# 1                            1.0
# 2                            1.0
# 3                            0.0
# 4                            4.0
# ...                          ...
# 15600                       45.0
# 15601                       11.0
# ...

# %%
# regroupement par pays pour une meilleur visibilité


df2g=df2z.groupby(['Zone']).sum()

# %%
df2g
# Out:
#                        Disponibilité alimentaire
# Zone
# Afghanistan                               2087.0
# Afrique du Sud                            3020.0
# Albanie                                   3188.0
# Algérie                                   3293.0
# Allemagne                                 3503.0
# ...                                          ...
# Émirats arabes unis                       3275.0
# Équateur                                  2346.0
# États-Unis d'Amérique                     3682.0
# Éthiopie                                  2129.0
# Îles Salomon                              2383.0
#
# [174 rows x 1 columns]

# %%
df3
# Out:
#                                         Zone  Année  pop_total
# 4                                Afghanistan   2017  36296.113
# 10                            Afrique du Sud   2017  57009.756
# 16                                   Albanie   2017   2884.169
# 22                                   Algérie   2017  41389.189
# 28                                 Allemagne   2017  82658.409
# ...                                      ...    ...        ...
# 1390  Venezuela (République bolivarienne du)   2017  29402.484
# 1396                                Viet Nam   2017  94600.648
# 1402                                   Yémen   2017  27834.819
# 1408                                  Zambie   2017  16853.599
# 1414                                Zimbabwe   2017  14236.595
#
# [236 rows x 3 columns]

# %%
# Jointure des deux bases sur la colonne 'Zone'

df_joint = pd.merge(df3, df2g, left_on="Zone", right_on="Zone")

# %%
df_joint
# Out:
#                                        Zone  Année  pop_total  \
# 0                               Afghanistan   2017  36296.113
# 1                            Afrique du Sud   2017  57009.756
# 2                                   Albanie   2017   2884.169
# 3                                   Algérie   2017  41389.189
# 4                                 Allemagne   2017  82658.409
# ..                                      ...    ...        ...
# 167  Venezuela (République bolivarienne du)   2017  29402.484
# 168                                Viet Nam   2017  94600.648
# 169                                   Yémen   2017  27834.819
# 170                                  Zambie   2017  16853.599
# 171                                Zimbabwe   2017  14236.595
#
#      Disponibilité alimentaire
# 0                       2087.0
# 1                       3020.0
# 2                       3188.0
# 3                       3293.0
# 4                       3503.0
# ...

# %%
# création de la colonne

df_joint['disponibilité alimentaire cal/pop']=((df_joint['pop_total']*1000)*(df_joint['Disponibilité alimentaire']))

# %%
###################### observation de la disponibilité alimentaire calorie * population

df_joint
# Out:
#                                        Zone  Année  pop_total  \
# 0                               Afghanistan   2017  36296.113
# 1                            Afrique du Sud   2017  57009.756
# 2                                   Albanie   2017   2884.169
# 3                                   Algérie   2017  41389.189
# 4                                 Allemagne   2017  82658.409
# ..                                      ...    ...        ...
# 167  Venezuela (République bolivarienne du)   2017  29402.484
# 168                                Viet Nam   2017  94600.648
# 169                                   Yémen   2017  27834.819
# 170                                  Zambie   2017  16853.599
# 171                                Zimbabwe   2017  14236.595
#
#      Disponibilité alimentaire  disponibilité alimentaire cal/pop
# 0                       2087.0                       7.574999e+10
# 1                       3020.0                       1.721695e+11
# ...

# %% [markdown]
# #### *Disponibilité alimentaire kcal/ans*

# %%
round(df_joint['disponibilité alimentaire cal/pop'].sum()*360)
# Out:
# 7530834465839160

# %%
### nombre de calorie par personne estimé à 2500


pop_nourrie=round(df_joint['disponibilité alimentaire cal/pop'].sum()/2500)

# %% [markdown]
# #### *Population mondiale pouvant être nourrie*

# %%
print(' la population mondiale pouvant être nourrie est de {:,}'.format(pop_nourrie))
# Out:
#  la population mondiale pouvant être nourrie est de 8,367,593,851

# %%
#### population pouvant être nourrie en pourcentage

pop_nourrie_p=round((pop_nourrie/pop_mondiale_2017)*100)

# %%
print('Cela représente {:,}% de la population mondiale'.format(pop_nourrie_p))
# Out:
# Cela représente 111% de la population mondiale

# %% [markdown]
# # **Représentation graphique**

# %%
#######" Graphique en barre "

names = ['population pouvant être nourrie', 'population mondiale'] 
values = [111,100]

plt.title('Représentation de la popoluation pouvant être nourrie en 2017')
plt.ylabel('Population en pourcentage')
plt.bar(names, values)
X=plt.bar(names, values)
X[0].set_color('g')
X[1].set_color('b')

plt.show()

# %%
###############################" question 3 ############################################"

# %%
df2z
# Out:
#                Zone                Produit   Origine  \
# 0       Afghanistan       Abats Comestible   animale
# 1       Afghanistan        Agrumes, Autres  vegetale
# 2       Afghanistan  Aliments pour enfants  vegetale
# 3       Afghanistan                 Ananas  vegetale
# 4       Afghanistan                Bananes  vegetale
# ...             ...                    ...       ...
# 15600  Îles Salomon       Viande de Suides   animale
# 15601  Îles Salomon    Viande de Volailles   animale
# 15602  Îles Salomon          Viande, Autre   animale
# 15603  Îles Salomon                    Vin  vegetale
# 15604  Îles Salomon         Épices, Autres  vegetale
#
#        Disponibilité alimentaire
# 0                            5.0
# 1                            1.0
# 2                            1.0
# 3                            0.0
# 4                            4.0
# ...                          ...
# 15600                       45.0
# 15601                       11.0
# ...

# %%
# condition pour avoir que l'origine vegetale


N=df2z["Origine"]=="vegetale"

# %%
tableau_vegetal=df2z[N]

# %%
# tableau avec que l'origine vegetal 

tableau_vegetal
# Out:
#                Zone                Produit   Origine  \
# 1       Afghanistan        Agrumes, Autres  vegetale
# 2       Afghanistan  Aliments pour enfants  vegetale
# 3       Afghanistan                 Ananas  vegetale
# 4       Afghanistan                Bananes  vegetale
# 6       Afghanistan                  Bière  vegetale
# ...             ...                    ...       ...
# 15595  Îles Salomon                 Sésame  vegetale
# 15596  Îles Salomon                    Thé  vegetale
# 15597  Îles Salomon                Tomates  vegetale
# 15603  Îles Salomon                    Vin  vegetale
# 15604  Îles Salomon         Épices, Autres  vegetale
#
#        Disponibilité alimentaire
# 1                            1.0
# 2                            1.0
# 3                            0.0
# 4                            4.0
# 6                            0.0
# ...                          ...
# 15595                        0.0
# 15596                        0.0
# ...

# %%
#### regroupement par zone

tableau_vegetal=tableau_vegetal.groupby(['Zone']).sum()

# %%
tableau_vegetal
# Out:
#                        Disponibilité alimentaire
# Zone
# Afghanistan                               1871.0
# Afrique du Sud                            2533.0
# Albanie                                   2203.0
# Algérie                                   2915.0
# Allemagne                                 2461.0
# ...                                          ...
# Émirats arabes unis                       2718.0
# Équateur                                  1732.0
# États-Unis d'Amérique                     2698.0
# Éthiopie                                  2005.0
# Îles Salomon                              2187.0
#
# [174 rows x 1 columns]

# %%
df3_2017
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1411    False
# 1412    False
# 1413    False
# 1414     True
# 1415    False
# Name: Année, Length: 1416, dtype: bool

# %%
#### Jointure entre la population de 2017 et le tableau vegetal sur la colonnz 'Zone'

df_joint1 = pd.merge(df3, tableau_vegetal, left_on='Zone', right_on='Zone')

# %%
df_joint1
# Out:
#                                        Zone  Année  pop_total  \
# 0                               Afghanistan   2017  36296.113
# 1                            Afrique du Sud   2017  57009.756
# 2                                   Albanie   2017   2884.169
# 3                                   Algérie   2017  41389.189
# 4                                 Allemagne   2017  82658.409
# ..                                      ...    ...        ...
# 167  Venezuela (République bolivarienne du)   2017  29402.484
# 168                                Viet Nam   2017  94600.648
# 169                                   Yémen   2017  27834.819
# 170                                  Zambie   2017  16853.599
# 171                                Zimbabwe   2017  14236.595
#
#      Disponibilité alimentaire
# 0                       1871.0
# 1                       2533.0
# 2                       2203.0
# 3                       2915.0
# 4                       2461.0
# ...

# %%
## création de la colonne

df_joint1['Disponibilité alimentaire cal/pop']=((df_joint1['pop_total']*1000)*(df_joint1['Disponibilité alimentaire']))

# %%
### disponibilité alimentaire ( vegetale )

df_joint1
# Out:
#                                        Zone  Année  pop_total  \
# 0                               Afghanistan   2017  36296.113
# 1                            Afrique du Sud   2017  57009.756
# 2                                   Albanie   2017   2884.169
# 3                                   Algérie   2017  41389.189
# 4                                 Allemagne   2017  82658.409
# ..                                      ...    ...        ...
# 167  Venezuela (République bolivarienne du)   2017  29402.484
# 168                                Viet Nam   2017  94600.648
# 169                                   Yémen   2017  27834.819
# 170                                  Zambie   2017  16853.599
# 171                                Zimbabwe   2017  14236.595
#
#      Disponibilité alimentaire  Disponibilité alimentaire cal/pop
# 0                       1871.0                       6.791003e+10
# 1                       2533.0                       1.444057e+11
# ...

# %%
pop_nourrie_veget=round(df_joint1['Disponibilité alimentaire cal/pop'].sum()/2500)

# %% [markdown]
# # **Population pouvant être nourrie que de produit végétal**

# %%
pop_nourrie_veget
# Out:
# 6904305685

# %%
print(' La population mondiale pouvant être nourrie de produit vegetale est de {:,} personnes'.format(pop_nourrie_veget))
# Out:
#  La population mondiale pouvant être nourrie de produit vegetale est de 6,904,305,685

# %%
pop_nourrie_veget_p=round((pop_nourrie_veget/pop_mondiale_2017)*100)

# %%
print(' La population mondiale pouvant être nourrie de produit vegetale est de {:,}%'.format(pop_nourrie_veget_p))
# Out:
#  La population mondiale pouvant être nourrie de produit vegetale est de 91%

# %%
#### Observation du type de produit

df2['Origine'].unique()
# Out:
# array(['animale', 'vegetale'], dtype=object)

# %%
pop_nourrie_animal=8367593851-6904305685

# %%
# population qui peut être nourrie de produit animal

pop_nourrie_animal
# Out:
# 1463288166

# %%
print(' La population mondiale pouvant être nourrie de produit animale est de l_ordre de 20%')
# Out:
#  La population mondiale pouvant être nourrie de produit animale est de l_ordre de 20%

# %% [markdown]
# # **Représentation graphique**

# %%
names = ['Produit animal','Produit végétal', 'Référence population'] 
values = [20,91,100]

plt.title('Représentation de la popoluation pouvant être nourrie en / Produit végétal/ Produit animal en 2017')
plt.ylabel('Population en Pourcentage')


plt.bar(names, values)
X=plt.bar(names, values)
X[0].set_color('orange')
X[1].set_color('r')
X[2].set_color('b')

plt.show()

# %%
names = ['Produit végétal', 'Référence population'] 
values = [91,100]

plt.title('Représentation de la popoluation pouvant être nourrie de produit végétal en 2017')
plt.ylabel('Population en Pourcentage')


plt.bar(names, values)
X=plt.bar(names, values)
X[0].set_color('r')
X[1].set_color('b')

plt.show()

# %%
#########################   Question 4  #####################################

# %% [markdown]
# ### **Etude sur la proportion de l'alimentation animale, les pertes, et celle utilisé pour les humains**

# %%
df2.head(40)
# Out:
#            Zone                  Produit   Origine  Aliments pour animaux  \
# 0   Afghanistan         Abats Comestible   animale                    NaN
# 1   Afghanistan          Agrumes, Autres  vegetale                    NaN
# 2   Afghanistan    Aliments pour enfants  vegetale                    NaN
# 3   Afghanistan                   Ananas  vegetale                    NaN
# 4   Afghanistan                  Bananes  vegetale                    NaN
# 5   Afghanistan             Beurre, Ghee   animale                    NaN
# 6   Afghanistan                    Bière  vegetale                    NaN
# 7   Afghanistan                      Blé  vegetale                    NaN
# 8   Afghanistan     Boissons Alcooliques  vegetale                    NaN
# 9   Afghanistan                     Café  vegetale                    NaN
# 10  Afghanistan       Coco (Incl Coprah)  vegetale                    NaN
# 11  Afghanistan                    Crème   animale                    NaN
# ...

# %%
DF2_lien=df2.groupby(['Zone']).sum()

# %%
DF2_lien
# Out:
#                        Aliments pour animaux  Autres Utilisations  \
# Zone
# Afghanistan                            768.0                415.0
# Afrique du Sud                        5309.0                876.0
# Albanie                                660.0                174.0
# Algérie                               4352.0               1707.0
# Allemagne                            30209.0               7711.0
# ...                                      ...                  ...
# Émirats arabes unis                   1174.0               2689.0
# Équateur                              1200.0               1909.0
# États-Unis d'Amérique               148432.0             154699.0
# Éthiopie                               685.0               3641.0
# Îles Salomon                             0.0                237.0
#
#                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Zone
# Afghanistan                                                    2087.0
# ...

# %%
DF2_lien['L1'].sum()
# Out:
# 1549150.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207 entries, 111 to 15126
# Data columns (total 19 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Zone                                                           207 non-null    object
#  1   Produit                                                        207 non-null    object
#  2   Origine                                                        207 non-null    object
#  3   Aliments pour animaux                                          207 non-null    float64
#  4   Autres Utilisations                                            207 non-null    float64
#  5   Disponibilité alimentaire (Kcal/personne/jour)                 207 non-null    float64
#  6   Disponibilité alimentaire en quantité (kg/personne/an)         207 non-null    float64
# ...

# %%
## Obsevation des sommes des colonnes qui doivent correspondre a la somme de la disponiblité intérieure

for elt in ['Disponibilité intérieure','Aliments pour animaux','Autres Utilisations','Nourriture','Pertes','Semences','Traitement','Production','Importations - Quantité','Exportations - Quantité','Variation de stock']:
    print ('somme de',elt, '{:,}'.format(df2[elt].sum()))
# Out:
# somme de Disponibilité intérieure 9,848,994.0
# somme de Aliments pour animaux 1,304,245.0
# somme de Autres Utilisations 865,023.0
# somme de Nourriture 4,876,258.0
# somme de Pertes 453,698.0
# somme de Semences 154,681.0
# somme de Traitement 2,204,687.0
# somme de Production 10,009,680.0
# somme de Importations - Quantité 1,296,053.0
# somme de Exportations - Quantité 1,352,158.0
# somme de Variation de stock -104,402.0

# %% [markdown]
# #### **Liens entre les colonnes**

# %%
# lien 1

# %%
a=df2['Aliments pour animaux'].sum()
b=df2['Autres Utilisations'].sum()
c=df2['Nourriture'].sum()
d=df2['Pertes'].sum()
e=df2['Semences'].sum()
f=df2['Traitement'].sum()

# %%
print(a+b+c+d+e+f)
# Out:
# 9858592.0

# %%
# lien 2

# %%
h=df2['Production'].sum()
i=df2['Importations - Quantité'].sum()
j=df2['Exportations - Quantité'].sum()
k=df2['Variation de stock'].sum()

# %%
print(h+i-j+k)
# Out:
# 9849173.0

# %%
# Les deux liens on la même valeur que la disponibilité intérieure

df2['Disponibilité intérieure'].sum()
# Out:
# 9848994.0

# %%
### séléction des colonnes pour l'étude des aliments cocnernant les animaux.

df2_1=df2[['Aliments pour animaux', 'Nourriture', 'Pertes']]

# %%
df2_1
# Out:
#        Aliments pour animaux  Nourriture  Pertes
# 0                        NaN        53.0     NaN
# 1                        NaN        39.0     2.0
# 2                        NaN         2.0     NaN
# 3                        NaN         0.0     NaN
# 4                        NaN        82.0     NaN
# ...                      ...         ...     ...
# 15600                    NaN         3.0     NaN
# 15601                    NaN         2.0     NaN
# 15602                    NaN         0.0     NaN
# 15603                    NaN         0.0     NaN
# 15604                    NaN         0.0     NaN
#
# [15605 rows x 3 columns]

# %%
Disponibilité_intérieure=round(df2['Disponibilité intérieure'].sum())

# %%
### somme de la disponibilité interieur mondiale


Disponibilité_intérieure
# Out:
# 9848994

# %%
for elt in ['Aliments pour animaux', 'Nourriture', 'Pertes']:
    
    print("Proportion de", elt, ":", "{:.1%}".format(df2[elt].sum()/Disponibilité_intérieure))
# Out:
# Proportion de Aliments pour animaux : 13.2%
# Proportion de Nourriture : 49.5%
# Proportion de Pertes : 4.6%

# %% [markdown]
# # **Représentation graphique**

# %%
names = 'Nourriture', 'aliment pour animaux', 'Pertes'
values = [49.5, 13.2,4.6]


New_Colors = ['green','blue','purple']
plt.barh(names,values , color=New_Colors)
New_Colors= ['green','blue','purple']

plt.title('Proportion de la disponibilité intérieur concernant la nourriture/Aliment pour animaux/Pertes')
plt.xlabel('proportion')
plt.show()

# %% [markdown]
# # **Etude sur les céréales de la base de données du site**
#
# http://www.fao.org/faostat/fr/#data

# %%
df_céréales=pd.read_csv(r"C:\Users\Rénato CATALFAMO\Desktop\céréales.csv")

# %%
df_céréales=df_céréales[['?l?ment','Produit','Valeur']]

# %%
df_céréales
# Out:
#                     aliment             Produit  Valeur
# 0     Aliments pour animaux     Bl? et produits     491
# 1                Nourriture     Bl? et produits    5749
# 2     Aliments pour animaux     Riz et produits       0
# 3                Nourriture     Riz et produits     646
# 4     Aliments pour animaux    Orge et produits      67
# ...                     ...                 ...     ...
# 2588             Nourriture  Millet et produits      30
# 2589  Aliments pour animaux  Sorgho et produits       2
# 2590             Nourriture  Sorgho et produits      87
# 2591  Aliments pour animaux    C?r?ales, Autres       0
# 2592             Nourriture    C?r?ales, Autres       3
#
# [2593 rows x 3 columns]

# %%
# renommage

df_céréales.rename(columns={'?l?ment': 'aliment'}, inplace=True)

# %%
# Filtarge

df_céréales_nourriture=df_céréales['aliment']=='Aliments pour animaux'

# %%
df_céréales_nourriture1=df_céréales[df_céréales_nourriture]

# %%
df_céréales_nourriture1
# Out:
#                     aliment             Produit  Valeur
# 0     Aliments pour animaux     Bl? et produits     491
# 2     Aliments pour animaux     Riz et produits       0
# 4     Aliments pour animaux    Orge et produits      67
# 6     Aliments pour animaux    Ma?s et produits     111
# 8     Aliments pour animaux  Seigle et produits       0
# ...                     ...                 ...     ...
# 2582  Aliments pour animaux    Ma?s et produits      31
# 2585  Aliments pour animaux              Avoine       1
# 2587  Aliments pour animaux  Millet et produits       2
# 2589  Aliments pour animaux  Sorgho et produits       2
# 2591  Aliments pour animaux    C?r?ales, Autres       0
#
# [1287 rows x 3 columns]

# %%
### classement par ordre decroissant sur la colonne 'Valeur'

df_céréales_nourriture2=df_céréales_nourriture1.sort_values(by='Valeur', ascending=False)

# %%
df_céréales_nourriture2.head(30)
# Out:
#                     aliment           Produit  Valeur
# 517   Aliments pour animaux  Ma?s et produits  184252
# 802   Aliments pour animaux  Ma?s et produits  134735
# 366   Aliments pour animaux  Ma?s et produits   45949
# 511   Aliments pour animaux   Bl? et produits   21192
# 134   Aliments pour animaux  Ma?s et produits   18040
# 830   Aliments pour animaux   Bl? et produits   17671
# 1570  Aliments pour animaux  Ma?s et produits   17197
# 513   Aliments pour animaux   Riz et produits   13960
# 1232  Aliments pour animaux  Ma?s et produits   10802
# 457   Aliments pour animaux  Ma?s et produits   10662
# 2532  Aliments pour animaux  Ma?s et produits   10331
# 1203  Aliments pour animaux  Ma?s et produits   10113
# 834   Aliments pour animaux  Orge et produits   10109
# 1100  Aliments pour animaux  Ma?s et produits    9762
# 756   Aliments pour animaux  Ma?s et produits    8997
# 66    Aliments pour animaux   Bl? et produits    8987
# ...

# %%
## agrégation

df_céréales_nourriture2=df_céréales_nourriture2.groupby(['aliment','Produit']).sum()

# %%
df_céréales_nourriture2
# Out:
#                                           Valeur
# aliment               Produit
# Aliments pour animaux Avoine               17297
#                       Bl? et produits     127093
#                       C?r?ales, Autres     21151
#                       Ma?s et produits    618298
#                       Millet et produits    3405
#                       Orge et produits     86409
#                       Riz et produits      43736
#                       Seigle et produits    6609
#                       Sorgho et produits   21987

# %%
df_céréales_nourriture2['Valeur'].unique()
# Out:
# array([618298, 127093,  86409,  43736,  21987,  21151,  17297,   6609,
#          3405], dtype=int64)

# %%
########### céréales consommer par les animaux !!!!





df_céréales_nourriture2=df_céréales_nourriture2.sort_values(by='Valeur',ascending=False)

# %%
df_céréales_nourriture2
# Out:
#                                           Valeur
# aliment               Produit
# Aliments pour animaux Ma?s et produits    618298
#                       Bl? et produits     127093
#                       Orge et produits     86409
#                       Riz et produits      43736
#                       Sorgho et produits   21987
#                       C?r?ales, Autres     21151
#                       Avoine               17297
#                       Seigle et produits    6609
#                       Millet et produits    3405

# %%
#### remise en place des index


df_céréales_nourriture2=df_céréales_nourriture2.reset_index()

# %%
df_céréales_nourriture2['Valeur'].unique()
# Out:
# array([618298, 127093,  86409,  43736,  21987,  21151,  17297,   6609,
#          3405], dtype=int64)

# %%
df_céréales_nourriture2['Produit'].unique()
# Out:
# array(['Ma?s et produits', 'Bl? et produits', 'Orge et produits',
#        'Riz et produits', 'Sorgho et produits', 'C?r?ales, Autres',
#        'Avoine', 'Seigle et produits', 'Millet et produits'], dtype=object)

# %% [markdown]
# # **Répartition des céréales chez les animaux graphique**

# %%
names = ['mais et produits', 'blé et produits', 'orge et produits', 'riz et produits', 'sorgho et produits',
         'céréales et autres', 'avoine','seigie et prduits', 'millet et prouits'] 


values = [618298, 127093,  86409,  43736,  21987,  21151,  17297,   6609,
         3405]

plt.title(' Répartition de l_utilisation des céréales des animaux')
plt.xlabel('valeur en tonne')


plt.barh(names, values,color=new_colors)
new_colors=['green','blue','purple','brown','teal','black','yellow','orange','grey']

plt.show()

# %%
df_céréales_nourriture2['produit'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'produit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-330-7093c730dc7e> in <module>
# ...

# %%
df_céréales_nourriture2.sum()
# Out:
# Valeur    945985
# dtype: int64

# %%
resul
# Out:
# Valeur    945985
# dtype: int64

# %%
df_céréales_N=df_céréales['aliment']=='Nourriture'

# %%
df_céréales_N=df_céréales[df_céréales_N]

# %%
df_céréales_N
# Out:
#          aliment             Produit  Valeur
# 1     Nourriture     Bl? et produits    5749
# 3     Nourriture     Riz et produits     646
# 5     Nourriture    Orge et produits      48
# 7     Nourriture    Ma?s et produits      49
# 9     Nourriture  Seigle et produits       0
# ...          ...                 ...     ...
# 2584  Nourriture  Seigle et produits       0
# 2586  Nourriture              Avoine       1
# 2588  Nourriture  Millet et produits      30
# 2590  Nourriture  Sorgho et produits      87
# 2592  Nourriture    C?r?ales, Autres       3
#
# [1306 rows x 3 columns]

# %%
df_céréales_NO=df_céréales_N.groupby(['aliment','Produit']).sum()

# %%
df_céréales_NO
# Out:
#                                Valeur
# aliment    Produit
# Nourriture Avoine                4870
#            Bl? et produits     495898
#            C?r?ales, Autres      7319
#            Ma?s et produits    139492
#            Millet et produits   21288
#            Orge et produits      7944
#            Riz et produits     580566
#            Seigle et produits    4616
#            Sorgho et produits   26933

# %%
df_céréales_NO=df_céréales_NO.sort_values(by='Valeur', ascending=False)

# %%
df_céréales_NO
# Out:
#                                Valeur
# aliment    Produit
# Nourriture Riz et produits     580566
#            Bl? et produits     495898
#            Ma?s et produits    139492
#            Sorgho et produits   26933
#            Millet et produits   21288
#            Orge et produits      7944
#            C?r?ales, Autres      7319
#            Avoine                4870
#            Seigle et produits    4616

# %%
#### remise en place des index

df_céréales_NO=df_céréales_NO.reset_index()

# %%
df_céréales_NO['Valeur'].unique()
# Out:
# array([580566, 495898, 139492,  26933,  21288,   7944,   7319,   4870,
#          4616], dtype=int64)

# %%
df_céréales_NO['Produit'].unique()
# Out:
# array(['Riz et produits', 'Bl? et produits', 'Ma?s et produits',
#        'Sorgho et produits', 'Millet et produits', 'Orge et produits',
#        'C?r?ales, Autres', 'Avoine', 'Seigle et produits'], dtype=object)

# %%
w=df_céréales_NO['Valeur'].sum()

# %%
w
# Out:
# 1288926

# %%
q=df_céréales_nourriture2['Valeur'].sum()

# %%
q
# Out:
# 945985

# %%
##### difference en pourcentage entre la nourriture des animaux et des humains

# %%
## difference en pourcentage (VF-VA/VA)*100

dif=round(((w-q)/q)*100,1)

# %%
dif
# Out:
# 36.3

# %% [markdown]
# #### Difference de consommation entre animal et humain en céréales

# %%
print('La difference de consommation en tonne entre l_alimentation humaine et animal en céréales et de {:,}%'.format(dif))
# Out:
# La difference de consommation en tonne entre l_alimentation humaine et animal en céréales et de 36.3%

# %% [markdown]
# # **Représentation graphique**

# %%
names = ['riz et produits', 'blé et produits', 'mais et produits', 'sorgho et produits', 'millet et produits',
         'orge et produit', 'céréales et autres','Avoine', 'Seigle et produits']  # recupération avec unique()


values = [580566, 495898, 139492,  26933,  21288,   7944,   7319,   4870, # Récupération avec unique()
         4616]

plt.title(' Répartition de l_utilisation des céréales des humains')
plt.xlabel('valeur en tonne')


plt.barh(names, values,color=new_colors)
new_colors=['green','blue','purple','brown','teal','black','yellow','orange','grey']

plt.show()

# %%
total_céréames=q+w

# %%
total_céréames
# Out:
# 2234911

# %% [markdown]
# ### **Graphique répartition des céréales**

# %%
label = "Répartition des céréales entre humain et animaux en 2017 "
labels = 'Céréales humain' , 'Céréales animaux'
x = [w,q]
explode = (0, 0) 

fig1, ax1 = plt.subplots()
ax1.pie( x, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=100)
ax1.axis('equal')  

plt.title(label , fontdict=None, loc=None, pad=None, y=None,fontweight="bold")
fig1.set_size_inches(15, 7)
plt.show()

# %% [markdown]
# # **Etude du manioc en Thaillande**

# %%
df2b['Zone'].unique()
# Out:
# array(['Afghanistan', 'Afrique du Sud', 'Albanie', 'Algérie', 'Allemagne',
#        'Angola', 'Antigua-et-Barbuda', 'Arabie saoudite', 'Argentine',
#        'Arménie', 'Australie', 'Autriche', 'Azerbaïdjan', 'Bahamas',
#        'Bangladesh', 'Barbade', 'Belgique', 'Belize', 'Bermudes',
#        'Bolivie (État plurinational de)', 'Bosnie-Herzégovine',
#        'Botswana', 'Brunéi Darussalam', 'Brésil', 'Bulgarie',
#        'Burkina Faso', 'Bélarus', 'Bénin', 'Cabo Verde', 'Cambodge',
#        'Cameroun', 'Canada', 'Chili', 'Chine - RAS de Hong-Kong',
#        'Chine - RAS de Macao', 'Chine, Taiwan Province de',
#        'Chine, continentale', 'Chypre', 'Colombie', 'Congo', 'Costa Rica',
#        'Croatie', 'Cuba', "Côte d'Ivoire", 'Danemark', 'Djibouti',
#        'Dominique', 'El Salvador', 'Espagne', 'Estonie', 'Eswatini',
#        'Fidji', 'Finlande', 'France', 'Fédération de Russie', 'Gabon',
#        'Gambie', 'Ghana', 'Grenade', 'Grèce', 'Guatemala', 'Guinée',
# ...

# %%
df2b
# Out:
#                Zone                Produit   Origine  Aliments pour animaux  \
# 0       Afghanistan       Abats Comestible   animale                    NaN
# 1       Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2       Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3       Afghanistan                 Ananas  vegetale                    NaN
# 4       Afghanistan                Bananes  vegetale                    NaN
# ...             ...                    ...       ...                    ...
# 15600  Îles Salomon       Viande de Suides   animale                    NaN
# 15601  Îles Salomon    Viande de Volailles   animale                    NaN
# 15602  Îles Salomon          Viande, Autre   animale                    NaN
# 15603  Îles Salomon                    Vin  vegetale                    NaN
# 15604  Îles Salomon         Épices, Autres  vegetale                    NaN
#
#        Autres Utilisations  Disponibilité alimentaire  \
# ...

# %%
df2b[thai_resultat].head()
# Out:
# Empty DataFrame
# Columns: [Zone, Produit, Origine, Aliments pour animaux, Autres Utilisations, Disponibilité alimentaire (Kcal/personne/jour), Disponibilité alimentaire en quantité (kg/personne/an), Disponibilité de matière grasse en quantité (g/personne/jour), Disponibilité de protéines en quantité (g/personne/jour), Disponibilité intérieure, Exportations - Quantité, Importations - Quantité, Nourriture, Pertes, Production, Semences, Traitement, Variation de stock]
# Index: []

# %%
## filtration 

thai=df2b['Zone']=='Thaïlande'

# %%
new_base=df2b[thai]

# %%
new_base
# Out:
#             Zone                 Produit   Origine  Aliments pour animaux  \
# 13759  Thaïlande        Abats Comestible   animale                    NaN
# 13760  Thaïlande         Agrumes, Autres  vegetale                    NaN
# 13761  Thaïlande  Alcool, non Comestible  vegetale                    NaN
# 13762  Thaïlande   Aliments pour enfants  vegetale                    NaN
# 13763  Thaïlande                  Ananas  vegetale                    NaN
# ...          ...                     ...       ...                    ...
# 13849  Thaïlande        Viande de Suides   animale                    NaN
# 13850  Thaïlande     Viande de Volailles   animale                    NaN
# 13851  Thaïlande           Viande, Autre   animale                    NaN
# 13852  Thaïlande                     Vin  vegetale                    NaN
# 13853  Thaïlande          Épices, Autres  vegetale                    NaN
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# ...

# %%
## filtration 

aa=new_base['Produit']=='Manioc'

# %%
#### Observation des resultats du manioc en thailande

etude_thai_manio=new_base[aa]

# %% [markdown]
# ### **Tableau général du manioc en Thaillande**

# %%
etude_thai_manio
# Out:
#             Zone Produit   Origine  Aliments pour animaux  \
# 13809  Thaïlande  Manioc  vegetale                 1800.0
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 13809               2081.0                                            40.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 13809                                               13.0
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 13809                                               0.05
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 13809                                               0.14
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 13809                    6264.0                  25214.0
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 13809                   1250.0       871.0  1511.0     30228.0       NaN
#
#        Traitement  Variation de stock
# ...

# %%
### récupération des colonnes essensiel


etude_thai_manio=etude_thai_manio[["Zone", "Produit", "Production", "Disponibilité intérieure"
                  ,"Exportations - Quantité", "Importations - Quantité", "Pertes" ]]

# %%
etude_thai_manio
# Out:
#             Zone Produit  Production  Disponibilité intérieure  \
# 13809  Thaïlande  Manioc     30228.0                    6264.0
#
#        Exportations - Quantité  Importations - Quantité  Pertes
# 13809                  25214.0                   1250.0  1511.0

# %%
etude_thai_manio=etude_thai_manio.iloc[0]

# %%
etude_thai_manio
# Out:
# Zone                        Thaïlande
# Produit                        Manioc
# Production                    30228.0
# Disponibilité intérieure       6264.0
# Exportations - Quantité       25214.0
# Importations - Quantité        1250.0
# Pertes                         1511.0
# Name: 13809, dtype: object

# %% [markdown]
# # **Représentation graphique du manioc**

# %%
label = "Utilisation du mnaioc en Thailande "
labels = 'Production', 'Disponibilité intérieure', 'Exportations - Quantité', 'Importations - Quantité', 'Pertes'
sizes = [etude_thai_manio[el] for el in labels]
explode = (0, 0,0, 0,0) 

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=50)
ax1.axis('equal') 

plt.title(label , fontdict=None, loc=None, pad=None, y=None,fontweight="bold")
fig1.set_size_inches(20, 7)
plt.show()

# %%
pr=etude_thai_manio['Production']

# %%
print(pr)
# Out:
# 13809    30228.0
# Name: Production, dtype: float64

# %%
exp=etude_thai_manio['Exportations - Quantité']

# %%
print(exp)
# Out:
# 13809    25214.0
# Name: Exportations - Quantité, dtype: float64

# %%
###### rapport entre l'exportation et la production

percent2 = int((exp*100)/pr)

# %%
print("Il y a {:,} % de la production du manioc de la Thailande exporté".format(percent2))
# Out:
# Il y a 83 % de la production du manioc de la Thailande exporté

# %% [markdown]
# # **Répresentation graphique de l'exportation du manioc**

# %%
label='Exportation du manioc en 2017'
fig1, ax1 = plt.subplots()


ax1.axis('equal') 

x = [83, 17]

plt.pie(x, labels = ['manioc exporté','manioc restant'], normalize=True,
       explode = [0,0],
       autopct = lambda x: str(round(x, 1)) + '%',
       colors = ['y', 'g']),
plt.title(label, fontdict=None, loc=None, pad=None, y=None,fontweight="bold")


fig1.set_size_inches(20, 7)
plt.show()

# %%
df4.rename(columns={'Valeur': 'pop_ss_nutrition'}, inplace=True)

# %%
## la filtration peut être réaliser en une fois. 

df4((['Zone']=='Thaïlande') & (df4['Année']=='2016-2018'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-955-8a7c3f9b9937> in <module>
#       1 ### filtration en une seul fois, probleme ????
#       2
# ----> 3 df4((['Zone']=='Thaïlande') & (df4['Année']=='2016-2018'))
#
# TypeError: 'DataFrame' object is not callable

# %%
## Filtration des bases en deux fois pour observer les données.

# %%
df4_thai=df4['Zone']=='Thaïlande'

# %%
table_thai=df4[df4_thai]

# %%
table_thai
# Out:
#            Zone      Année pop_ss_nutrition
# 1110  Thaïlande  2012-2014              6.2
# 1111  Thaïlande  2013-2015                6
# 1112  Thaïlande  2014-2016              5.9
# 1113  Thaïlande  2015-2017                6
# 1114  Thaïlande  2016-2018              6.2
# 1115  Thaïlande  2017-2019              6.5

# %%
Resultat_thai=table_thai['Année']=='2016-2018'

# %%
##### thailande et population ss-nutrition

table_thai_Final=table_thai[Resultat_thai]

# %%
######## table ############

table_thai_Final
# Out:
#            Zone      Année pop_ss_nutrition
# 1114  Thaïlande  2016-2018              6.2

# %%
cal=table_thai_Final['pop_ss_nutrition']

# %%
cal
# Out:
# 1114    6.2
# Name: pop_ss_nutrition, dtype: object

# %%
pop_ss_thaillande=pd.to_numeric(cal, downcast="float")*1000000

# %%
### personnes en sous_nutrition en thailande en 2017


pop_ss_thaillande
# Out:
# 1114    6.200000e+06
# Name: pop_ss_nutrition, dtype: float64

# %%
pop_ss_thaillande=pop_ss_thaillande.sum()

# %%
pop_ss_thaillande
# Out:
# 6200.0

# %%
df3
# Out:
#              Zone  Année  pop_total
# 0     Afghanistan   2013  32269.589
# 1     Afghanistan   2014  33370.794
# 2     Afghanistan   2015  34413.603
# 3     Afghanistan   2016  35383.032
# 4     Afghanistan   2017  36296.113
# ...           ...    ...        ...
# 1411     Zimbabwe   2014  13586.707
# 1412     Zimbabwe   2015  13814.629
# 1413     Zimbabwe   2016  14030.331
# 1414     Zimbabwe   2017  14236.595
# 1415     Zimbabwe   2018  14438.802
#
# [1416 rows x 3 columns]

# %%
pop_thai=df3['Zone']=='Thaïlande'

# %%
pop_thai=df3[pop_thai]

# %%
pop_thai
# Out:
#            Zone  Année  pop_total
# 1308  Thaïlande   2013  68144.518
# 1309  Thaïlande   2014  68438.746
# 1310  Thaïlande   2015  68714.511
# 1311  Thaïlande   2016  68971.308
# 1312  Thaïlande   2017  69209.810
# 1313  Thaïlande   2018  69428.453

# %%
pop_thai2=pop_thai['Année']==2017

# %%
#### table de la population thailandaise

table_pop_thai=pop_thai[pop_thai2]

# %%
table_pop_thai
# Out:
#            Zone  Année  pop_total
# 1312  Thaïlande   2017   69209.81

# %%
resultat_de_pop_thai=table_pop_thai['pop_total']*1000

# %%
resultat_de_pop_thai=resultat_de_pop_thai.sum()

# %%
resultat_de_pop_thai
# Out:
# 69209810.0

# %%
pourcentage_de_ss_nut_thai=round((pop_ss_thaillande/resultat_de_pop_thai)*100,1)

# %%
pourcentage_de_ss_nut_thai=pourcentage_de_ss_nut_thai.sum()

# %%
pourcentage_de_ss_nut_thai
# Out:
# 9.0

# %%
print("Il y a {:,} % de la population Thailandaise en sous-nutrition".format(pourcentage_de_ss_nut_thai))
# Out:
# Il y a 9.0 % de la population Thailandaise en sous-nutrition

# %%
### 9% de la population en ss_nutrition avec une exportation du manioc de 83%. 

### La population thailandaise exporte au lieu de se nourir.

# %% [markdown]
# # **Représention graphique de la population en sous_nutrition de la Thailande**

# %%
names = ['pop en ss-nutrition', 'pop thai'] 
values = [9,100]

plt.title('Représentation de la pop thai en ss-nutrition')
plt.ylabel('Population en Pourcentage')
plt.bar(names, values)
X=plt.bar(names, values)
X[0].set_color('r')
X[1].set_color('b')

plt.show()

# %%
plt.figure
values = [9,100]
plt.pie(values)
# Out:
# ([<matplotlib.patches.Wedge at 0x13505d94070>,
# ...
#  [Text(1.0631991447919917, 0.282148149938251, ''),
#   Text(-1.0631991580002986, -0.28214810016630665, '')])

# %%
## autre visuel

plt.figure
x = [9, 91]
plt.title('Représentation de la pop thai en ss-nutrition')
plt.pie(x, labels = ['pop-ss-nut','pop-thai'], normalize=True,
       explode = [0,0],
       autopct = lambda x: str(round(x, 1)) + '%',
       colors = ['r', 'b'])
plt.show()

# %% [markdown]
# # **Proportion général de la Thaillande**

# %%
thai_general=new_base.groupby(['Zone']).sum()

# %%
thai_general
# Out:
#            Aliments pour animaux  Autres Utilisations  \
# Zone
# Thaïlande                 9561.0               4210.0
#
#            Disponibilité alimentaire (Kcal/personne/jour)  \
# Zone
# Thaïlande                                          2785.0
#
#            Disponibilité alimentaire en quantité (kg/personne/an)  \
# Zone
# Thaïlande                                             586.23
#
#            Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Zone
# Thaïlande                                              58.57
#
#            Disponibilité de protéines en quantité (g/personne/jour)  \
# Zone
# Thaïlande                                              60.85
#
#            Disponibilité intérieure  Exportations - Quantité  \
# Zone
# Thaïlande                  158130.0                  50430.0
#
#            Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# Zone
# Thaïlande                  11335.0     39283.0  5749.0    201764.0     823.0
# ...

# %%
thai_general=thai_general[["Production", "Disponibilité intérieure"
                  ,"Exportations - Quantité", "Importations - Quantité", "Pertes" ]]

# %%
thai_general=thai_general.iloc[0]

# %%
label = "Proportion général en Thailandaise "
labels = 'Production', 'Disponibilité intérieure', 'Exportations - Quantité', 'Importations - Quantité', 'Pertes'
sizes = [thai_general[el] for el in labels]
explode = (0, 0,0, 0,0) 

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=50)
ax1.axis('equal') 

plt.title(label , fontdict=None, loc=None, pad=None, y=None,fontweight="bold")
fig1.set_size_inches(20, 7)
plt.show()
